# %%
import os, sys
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision

from torch.utils.data import random_split
from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data.dataloader import DataLoader

# %%
data_path = '/home/xxx/torch/data'

classes = os.listdir(data_path + '/train')

print(classes)
# Out:
# ['dogs', 'cats']

# %%
transform = transforms.Compose([transforms.RandomResizedCrop(180),
                                transforms.ToTensor(),
                                
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
data  = ImageFolder(data_path + '/train', transform = transform)

print(data)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 8000
#     Root location: /home/xxx/torch/data/train
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(180, 180), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %%
img, label = data[1]
print(img.shape, label)
img
# Out:
# torch.Size([3, 180, 180]) 0
# tensor([[[-0.7333, -0.7255, -0.7255,  ...,  0.0902,  0.0902,  0.0745],
#          [-0.8039, -0.8039, -0.8824,  ...,  0.0902,  0.0902,  0.0667],
#          [-0.6314, -0.6706, -0.7098,  ...,  0.0902,  0.0902,  0.0667],
#          ...,
#          [-0.3804, -0.3882, -0.3804,  ...,  0.4510,  0.4588,  0.4353],
#          [-0.3255, -0.2941, -0.2863,  ...,  0.4902,  0.4902,  0.4588],
#          [-0.1686, -0.1843, -0.2000,  ...,  0.5137,  0.5137,  0.4745]],
#
#         [[-0.8039, -0.8039, -0.7961,  ...,  0.3647,  0.3647,  0.3490],
#          [-0.7333, -0.7333, -0.7882,  ...,  0.3647,  0.3647,  0.3412],
#          [-0.8510, -0.8588, -0.8510,  ...,  0.3647,  0.3647,  0.3412],
#          ...,
#          [-0.4902, -0.4980, -0.4902,  ...,  0.4431,  0.4353,  0.3961],
#          [-0.4275, -0.3882, -0.3804,  ...,  0.4824,  0.4667,  0.4275],
#          [-0.2627, -0.2863, -0.2941,  ...,  0.5059,  0.4902,  0.4353]],
#
# ...

# %%
print(data.classes)
# Out:
# ['cats', 'dogs']

# %%
def example(img, label):
    print('Label: ', data.classes[label], "("+str(label)+")")
    plt.imshow(img.permute(1, 2, 0))

# %%
example(*data[])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label:  dogs (1)

# %%
random_seed = 369
torch.manual_seed(random_seed)

# %%
val_size = 2000
train_size = len(data) - val_size

train, val = random_split(data, [train_size, val_size])
print(len(train))
print(len(val))
# Out:
# 6000
# 2000

# %%
batch_size = 128

train_dl = DataLoader(train, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
val_dl  = DataLoader(val, batch_size * 2, shuffle = True, num_workers = 4, pin_memory = True)
